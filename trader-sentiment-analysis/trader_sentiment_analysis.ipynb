# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (1.54.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: packaging>=20 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (23.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.16.0)
# Requirement already satisfied: colorama in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\karunya s\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

st.set_page_config(page_title="Trader Sentiment Dashboard", layout="wide")

# --------------------------------------------------
# Title
# --------------------------------------------------
st.title("📊 Trader Performance vs Market Sentiment")
st.markdown(
    "Interactive dashboard to explore how **Fear vs Greed** market sentiment "
    "impacts trader behavior and performance on Hyperliquid."
)

# --------------------------------------------------
# Load Data
# --------------------------------------------------
@st.cache_data
def load_data():
    sentiment = pd.read_csv("data/fear_greed.csv")
    trades = pd.read_csv("data/trader_data.csv")

    # Sentiment processing
    sentiment['timestamp'] = pd.to_datetime(sentiment['timestamp'])
    sentiment['date'] = sentiment['timestamp'].dt.date

    # Trader processing
    trades['Timestamp'] = pd.to_datetime(trades['Timestamp'])
    trades['date'] = trades['Timestamp'].dt.date

    daily_trades = trades.groupby(['Account', 'date']).agg(
        daily_pnl=('Closed PnL', 'sum'),
        trade_count=('Closed PnL', 'count'),
        avg_trade_size=('Size USD', 'mean'),
        long_trades=('Side', lambda x: (x == 'BUY').sum()),
        short_trades=('Side', lambda x: (x == 'SELL').sum())
    ).reset_index()

    daily_trades['long_short_ratio'] = (
        daily_trades['long_trades'] / (daily_trades['short_trades'] + 1)
    )

    merged = daily_trades.merge(
        sentiment[['date', 'classification']],
        on='date',
        how='left'
    )

    merged['win'] = merged['daily_pnl'] > 0

    win_rate = (
        merged.groupby('Account')['win']
        .mean()
        .reset_index(name='win_rate')
    )

    merged = merged.merge(win_rate, on='Account', how='left')
    merged['drawdown_proxy'] = merged['daily_pnl'].clip(upper=0)

    merged['activity_segment'] = pd.qcut(
        merged['trade_count'], q=2,
        labels=['Low Activity', 'High Activity']
    )

    merged['consistency_segment'] = merged['win_rate'].apply(
        lambda x: 'Consistent' if x >= 0.5 else 'Inconsistent'
    )

    return merged

df = load_data()

# --------------------------------------------------
# Sidebar Filters
# --------------------------------------------------
st.sidebar.header("🔎 Filters")

sentiment_filter = st.sidebar.multiselect(
    "Select Market Sentiment",
    options=df['classification'].dropna().unique(),
    default=df['classification'].dropna().unique()
)

activity_filter = st.sidebar.multiselect(
    "Select Activity Segment",
    options=df['activity_segment'].unique(),
    default=df['activity_segment'].unique()
)

filtered_df = df[
    (df['classification'].isin(sentiment_filter)) &
    (df['activity_segment'].isin(activity_filter))
]

# --------------------------------------------------
# KPI Section
# --------------------------------------------------
st.subheader("📌 Key Metrics")

col1, col2, col3 = st.columns(3)

col1.metric(
    "Average Daily PnL",
    round(filtered_df['daily_pnl'].mean(), 2)
)

col2.metric(
    "Win Rate",
    f"{round(filtered_df['win'].mean() * 100, 2)}%"
)

col3.metric(
    "Avg Trades / Day",
    round(filtered_df['trade_count'].mean(), 2)
)

# --------------------------------------------------
# Performance by Sentiment
# --------------------------------------------------
st.subheader("🔥 Performance by Market Sentiment")

perf = filtered_df.groupby('classification')[['daily_pnl', 'win']].mean()

st.dataframe(perf)

fig, ax = plt.subplots()
perf['daily_pnl'].plot(kind='bar', ax=ax)
ax.set_title("Average Daily PnL by Sentiment")
ax.set_ylabel("Daily PnL")
st.pyplot(fig)

# --------------------------------------------------
# Trader Behavior
# --------------------------------------------------
st.subheader("🧠 Trader Behavior")

behavior = filtered_df.groupby('classification')[
    ['trade_count', 'avg_trade_size']
].mean()

st.dataframe(behavior)

# --------------------------------------------------
# Segmentation View
# --------------------------------------------------
st.subheader("👥 Trader Segmentation")

seg = filtered_df.groupby('consistency_segment')[
    ['daily_pnl', 'trade_count']
].mean()

st.dataframe(seg)

# --------------------------------------------------
# Footer
# --------------------------------------------------
st.markdown("---")
st.markdown(
    "📈 **Insight:** Consistent traders tend to achieve more stable profitability, "
    "while high-activity traders show higher risk during Fear periods."
)
